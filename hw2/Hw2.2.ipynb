# %%
import pandas as pd
file = r"C:\Users\kuzik\Downloads\2017_jun_final.csv"
poll = pd.read_csv(file)

# %%
poll.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
# 3                               400   Одесса      до 200 человек  ...
# 4                               500   Другой       до 10 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# 1        True       выше среднего                        Веб-разработка
# 2       False             средний  Веб-разработка,Корпоративные системы
# 3       False       ниже среднего   Desktop Applications,Веб-разработка
# 4       False             средний   Desktop Applications,Веб-разработка
#
#        Дата.заполнения                                         User.Agent  \
# 0  12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2  12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3  12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4  12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
#
#     exp current_job_exp salary Валюта  cls
# 0   0.5             0.5    400    NaN   QA
# 1   0.0             0.0    430    NaN   QA
# 2   4.0             1.0   2500    NaN  DEV
# 3   5.0             4.0   2000    NaN  DEV
# 4  10.0             0.5   4500    NaN  DEV
#
# [5 rows x 25 columns]

# %%
poll.shape
# Out:
# (8704, 25)

# %%
poll.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %%
poll.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Валюта                              8694
# cls                                 1574
# dtype: int64

# %%
poll=poll.drop(columns=['Специализация', 'Университет', 'Предметная.область', 'Валюта', 'cls'])

# %%
poll.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Валюта                              8694
# cls                                 1574
# dtype: int64

# %%
poll.dropna()
poll.shape
# Out:
# (8704, 25)

# %%
python_data = pd.read_csv(file)

# %%
python_data = python_data.dropna(subset=['Язык.программирования'])

# %%
python_data = python_data[python_data["Язык.программирования"] == 'Python']

# %%
python_data.shape
# Out:
# (207, 25)

# %%
python_data_grp = python_data.groupby(by=['Должность'])
python_data_grp.agg({'Зарплата.в.месяц' : ['max', 'min']})
# Out:
#                          Зарплата.в.месяц
#                                       max   min
# Должность
# Junior Software Engineer             1250   100
# Senior Software Engineer             9200  1300
# Software Engineer                    5400   500
# System Architect                     5000  3000
# Technical Lead                       6200  1425

# %%
def fill_avg_salary():
    avg_selary = python_data_grp.agg({'Зарплата.в.месяц' : ['mean']})
    return avg_selary

# %%
avg_salary = fill_avg_salary()

# %%
avg_salary
# Out:
#                          Зарплата.в.месяц
#                                      mean
# Должность
# Junior Software Engineer       560.841270
# Senior Software Engineer      3387.096774
# Software Engineer             1799.070000
# System Architect              4000.000000
# Technical Lead                3165.909091

# %%
import numpy as np
python_data.insert(7, "avg", np.nan)

# %%
python_data.apply(avg_salary ,axis=1, raw=False)
python_data['avg'] = python_data.groupby(['Должность'])['Зарплата.в.месяц'].transform('mean')

# %%
python_data
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 12      13         Software Engineer                Python           NaN
# 68      69         Software Engineer                Python           NaN
# 87      88  Junior Software Engineer                Python           NaN
# 114    115  Junior Software Engineer                Python           NaN
# 143    144  Junior Software Engineer                Python           NaN
# ...    ...                       ...                   ...           ...
# 8546  8547         Software Engineer                Python           NaN
# 8625  8626         Software Engineer                Python           NaN
# 8635  8636  Senior Software Engineer                Python           NaN
# 8673  8674  Junior Software Engineer                Python           NaN
# 8695  8696         Software Engineer                Python           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 12                   1             меньше 3 месяцев               800
# 68                 1.5                          0.5               900
# 87                 0.5                          0.5               600
# 114                1.5                          0.5               685
# 143                  1                            1               750
# ...                ...                          ...               ...
# 8546                 5                            1              2000
# 8625                 4                            1              1750
# 8635    10 и более лет             меньше 3 месяцев              4000
# 8673               0.5                          0.5               350
# 8695                 1                          0.5              1500
#
#               avg  Изменение.зарплаты.за.12.месяцев      Город  ...  \
# 12    1799.070000                               200       Киев  ...
# 68    1799.070000                               900       Киев  ...
# 87     560.841270                                 0       Киев  ...
# 114    560.841270                               250       Киев  ...
# 143    560.841270                               250       Киев  ...
# ...           ...                               ...        ...  ...
# 8546  1799.070000                               800  Запорожье  ...
# 8625  1799.070000                                 0       Киев  ...
# 8635  3387.096774                              1300   Удаленно  ...
# 8673   560.841270                                50       Киев  ...
# 8695  1799.070000                              1000       Киев  ...
#
#      Уровень.английского         Предметная.область      Дата.заполнения  \
# 12         ниже среднего      Веб-разработка,Другое  12/06/2017 13:05:54
# 68         выше среднего             Веб-разработка  12/06/2017 13:11:17
# 87         выше среднего   Веб-разработка,eCommerce  12/06/2017 13:12:25
# 114              средний                     Другое  12/06/2017 13:14:52
# 143        выше среднего             Веб-разработка  12/06/2017 13:19:10
# ...                  ...                        ...                  ...
# 8546             средний             Веб-разработка  10/07/2017 14:11:26
# 8625             средний             Веб-разработка  11/07/2017 16:15:40
# 8635       выше среднего             Веб-разработка  11/07/2017 17:51:36
# 8673             средний             Веб-разработка  12/07/2017 09:37:16
# 8695             средний  Финансы и банки,eCommerce  12/07/2017 14:39:21
#
#                                              User.Agent   exp current_job_exp  \
# 12    Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   1.0             0.0
# 68    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.5             0.5
# 87    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   0.5             0.5
# 114   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.5             0.5
# 143   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0             1.0
# ...                                                 ...   ...             ...
# 8546  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...   5.0             1.0
# 8625  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   4.0             1.0
# 8635  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  10.0             0.0
# 8673  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   0.5             0.5
# 8695  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0             0.5
#
#       salary Валюта  cls   avg_salary
# 12       800    NaN  DEV  1799.070000
# 68       900    NaN  DEV  1799.070000
# 87       600    NaN  DEV   560.841270
# 114      685    NaN  DEV   560.841270
# 143      750    NaN  DEV   560.841270
# ...      ...    ...  ...          ...
# 8546    2000    NaN  DEV  1799.070000
# 8625    1750    NaN  DEV  1799.070000
# 8635    4000    NaN  DEV  3387.096774
# 8673     350    NaN  DEV   560.841270
# 8695    1500    NaN  DEV  1799.070000
#
# [207 rows x 27 columns]

# %%
python_data['avg'].describe()
# Out:
# count     207.000000
# mean     1753.937198
# std       996.562606
# min       560.841270
# 25%       560.841270
# 50%      1799.070000
# 75%      1799.070000
# max      4000.000000
# Name: avg, dtype: float64

# %%
python_data.to_csv("data.csv", index=False)
