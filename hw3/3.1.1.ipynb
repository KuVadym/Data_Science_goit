# %%
import pandas as pd
import numpy as np

# %%
list_tables = pd.read_html(f"https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8#%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C")
born_table = list_tables[10]

# %%
born_table.head()
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %%
born_table.shape
# Out:
# (28, 9)

# %%
new_born_table = born_table.replace("—", np.nan)

# %%
new_born_table.iloc[:,[2,3,4,5,6,7,8]]
# Out:
#      1960   1970  1990  2000  2012 2014 2019
# 0   206.0  160.0   130    73   126  NaN  NaN
# 1   192.0  142.0   124    84   112  109   76
# 2   250.0  179.0   153   112   148  141  101
# 3   204.0  151.0   123    71   112  111   71
# 4   214.0  140.0   109    61    98   82  NaN
# 5   223.0  159.0   129    89   122  120   79
# 6   273.0  207.0   168   115   151  146  104
# 7   197.0  150.0   124    71   106  106   68
# 8   248.0  182.0   155   103   124  122   88
# 9   189.0  156.0   123    73   122  121   80
# 10  171.0  145.0   126    79   110  108   68
# 11  235.0  144.0   116    62    96   51  NaN
# 12  240.0  171.0   140    91   119  119   87
# 13  194.0  155.0   137    80   115  112   71
# 14  192.0  148.0   126    80   127  123   88
# 15  163.0  131.0   118    70    99  100   65
# 16  267.0  193.0   158   118   159  148  107
# 17  184.0  132.0   115    70    97   92   60
# 18  216.0  157.0   142    92   113  109   76
# 19  173.0  140.0   114    68    99  101   68
# ...

# %%
new_born_table
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82  NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51  NaN
# ...

# %%
new_born_table.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %%
table_without_NaN = new_born_table.replace(np.nan, 0)

# %%
table_without_NaN.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %%
new_born_table.isnull().sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %%
new_born_table=new_born_table.drop(27)

# %%
new_born_table["2014"] = pd.to_numeric(new_born_table["2014"])
new_born_table["2019"] = pd.to_numeric(new_born_table["2019"])

# %%
new_born_table=new_born_table.fillna({"1950": new_born_table["1950"].mean(), "1960": new_born_table["1960"].mean(), "1970": new_born_table["1970"].mean(), "1990": new_born_table["1990"].mean(), "2000": new_born_table["2000"].mean(), "2012": new_born_table["2012"].mean(), "2014": new_born_table["2014"].mean(), "2019": new_born_table["2019"].mean()})

# %%
new_born_table
# Out:
#                Регіон    1950        1960   1970  1990  2000  2012    2014  \
# 0                Крим  230.00  206.000000  160.0   130    73   126  111.44
# 1           Вінницька  224.00  192.000000  142.0   124    84   112  109.00
# 2           Волинська  247.00  250.000000  179.0   153   112   148  141.00
# 3    Дніпропетровська  204.00  204.000000  151.0   123    71   112  111.00
# 4            Донецька  271.00  214.000000  140.0   109    61    98   82.00
# 5         Житомирська  261.00  223.000000  159.0   129    89   122  120.00
# 6        Закарпатська  314.00  273.000000  207.0   168   115   151  146.00
# 7          Запорізька  219.00  197.000000  150.0   124    71   106  106.00
# 8   Івано-Франківська  243.00  248.000000  182.0   155   103   124  122.00
# 9            Київська  204.00  189.000000  156.0   123    73   122  121.00
# 10     Кіровоградська  216.00  171.000000  145.0   126    79   110  108.00
# ...

# %%
new_born_table.loc[new_born_table['2019'] > new_born_table['2019'].mean()].iloc[:,[0,8]]
# Out:
#                Регіон   2019
# 2           Волинська  101.0
# 6        Закарпатська  104.0
# 8   Івано-Франківська   88.0
# 12          Львівська   87.0
# 14            Одеська   88.0
# 16         Рівненська  107.0
# 20         Херсонська   81.0
# 23        Чернівецька   92.0
# 25               Київ  110.0

# %%
new_born_table.loc[new_born_table['2014'] == new_born_table['2014'].max()].iloc[:,[0,7]]
# Out:
#         Регіон   2014
# 16  Рівненська  148.0

# %%
index = new_born_table['Регіон']
new_born_table['2019'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
born_val_2019 = new_born_table['2019'].tolist()
index = new_born_table['Регіон'].tolist()
df = pd.DataFrame({'born_in_2019':born_val_2019}, index = index)
ax = df.plot.barh()
ax
# Out:
# <AxesSubplot:>

# %%
born_val_2019 = new_born_table['2019'].tolist()
index = new_born_table['Регіон']
df = pd.DataFrame({'born_in_2019':born_val_2019,}, index = index)
ax = df.plot.bar()
ax
# Out:
# <AxesSubplot:xlabel='Регіон'>

# %%
born_val_2019
# Out:
# [80.17391304347827,
#  76.0,
#  101.0,
#  71.0,
#  80.17391304347827,
#  79.0,
#  104.0,
#  68.0,
#  88.0,
#  80.0,
#  68.0,
#  80.17391304347827,
#  87.0,
#  71.0,
#  88.0,
#  65.0,
#  107.0,
#  60.0,
#  76.0,
#  68.0,
#  81.0,
#  79.0,
#  64.0,
#  92.0,
#  61.0,
#  110.0,
#  80.17391304347827]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(index ,born_val_2019, label='Народжуваність в Україні в 2019 р. на 10.000 осіб')
plt.xticks(rotation=90)
plt.xlabel('Область', fontsize='small', color='black')
plt.ylabel('Народжуваність на 10.000 населення', fontsize='small', color='black')
plt.legend()
plt.show()

# %%
plt.bar(index ,born_val_2019, label='Народжуваність в Україні в 2019 р. на 10.000 осіб')
plt.xticks(rotation=90)
plt.xlabel('Область', fontsize='small', color='black')
plt.ylabel('Народжуваність на 10.000 населення', fontsize='small', color='black')
plt.legend()
plt.show()

# %%
plt.pie(born_val_2019, labels=index)
plt.xticks(rotation=90)
plt.show()
